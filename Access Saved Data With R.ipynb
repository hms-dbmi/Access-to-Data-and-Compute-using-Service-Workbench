# %% [markdown]
# # Access Saved Data With R

# %%
# As a default, we assume the save_location as the home folder
save_location = "~/SageMaker/"

# REMINDER : In order to save data or code in a loaction that will persist after mandatory SageMaker updates,
# as well as across any SageMaker workspace connected to the same project, you must save files in your 
# study-specific folder
#
# In order to access to your specific study folder, uncomment the following line of code,
# and replace {STUDY FOLDER NAME} with the name of the study you selected when creating this workspace
# (ex: "CLINAQ-NAME")

#save_location = "~/SageMaker/studies/{STUDY FOLDER NAME}/"

# %% [markdown]
# We can then load the csv data file into this notebook, and run any analysis needed via R

# %%
previous_results = read.csv(paste0(save_location, "results.csv"))
previous_results
# Out:
#    X CONCEPT_PATH
# 1  0 \\i2b2\\Demographics\\Age\\0-9 years old\\0 years old\\01 months\\
# 2  1 \\i2b2\\Demographics\\Age\\0-9 years old\\0 years old\\02 months\\
# 3  2 \\i2b2\\Demographics\\Age\\0-9 years old\\0 years old\\03 months\\
# 4  3 \\i2b2\\Demographics\\Age\\0-9 years old\\0 years old\\04 months\\
# 5  4 \\i2b2\\Demographics\\Age\\0-9 years old\\0 years old\\05 months\\
# 6  5 \\i2b2\\Demographics\\Age\\0-9 years old\\0 years old\\06 months\\
# 7  6 \\i2b2\\Demographics\\Age\\0-9 years old\\0 years old\\07 months\\
# 8  7 \\i2b2\\Demographics\\Age\\0-9 years old\\0 years old\\08 months\\
# 9  8 \\i2b2\\Demographics\\Age\\0-9 years old\\0 years old\\09 months\\
# 10 9 \\i2b2\\Demographics\\Age\\0-9 years old\\0 years old\\10 months\\
#    CONCEPT_CD   NAME_CHAR
# 1  DEM|AGE:0.1  01 months
# 2  DEM|AGE:0.2  02 months
# 3  DEM|AGE:0.3  03 months
# 4  DEM|AGE:0.4  04 months
# 5  DEM|AGE:0.5  05 months
# 6  DEM|AGE:0.6  06 months
# 7  DEM|AGE:0.7  07 months
# ...
